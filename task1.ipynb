# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("worldpopulationdata.csv")

# %%
df.head()
# Out:
#          Series Name  Series Code    Country Name Country Code        2022  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  41128771.0
# 1  Population, total  SP.POP.TOTL         Albania          ALB   2775634.0
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  44903225.0
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     44273.0
# 4  Population, total  SP.POP.TOTL         Andorra          AND     79824.0
#
#          2021        2020        2019        2018        2017  ...  \
# 0  40099462.0  38972230.0  37769499.0  36686784.0  35643418.0  ...
# 1   2811666.0   2837849.0   2854191.0   2866376.0   2873457.0  ...
# 2  44177969.0  43451666.0  42705368.0  41927007.0  41136546.0  ...
# 3     45035.0     46189.0     47321.0     48424.0     49463.0  ...
# 4     79034.0     77700.0     76343.0     75013.0     73837.0  ...
#
#          2010        2009        2008        2007        2006        2005  \
# ...

# %% [markdown]
# ## Total Population

# %%
total_population=df[df['Series Code']=='SP.POP.TOTL']
total_population
# Out:
#            Series Name  Series Code           Country Name Country Code  \
# 0    Population, total  SP.POP.TOTL            Afghanistan          AFG
# 1    Population, total  SP.POP.TOTL                Albania          ALB
# 2    Population, total  SP.POP.TOTL                Algeria          DZA
# 3    Population, total  SP.POP.TOTL         American Samoa          ASM
# 4    Population, total  SP.POP.TOTL                Andorra          AND
# ..                 ...          ...                    ...          ...
# 212  Population, total  SP.POP.TOTL  Virgin Islands (U.S.)          VIR
# 213  Population, total  SP.POP.TOTL     West Bank and Gaza          PSE
# 214  Population, total  SP.POP.TOTL            Yemen, Rep.          YEM
# 215  Population, total  SP.POP.TOTL                 Zambia          ZMB
# 216  Population, total  SP.POP.TOTL               Zimbabwe          ZWE
#
#            2022        2021        2020        2019        2018        2017  \
# ...

# %% [markdown]
# ## Female Population

# %%
female_population=df[(df['Series Code']=='SP.POP.TOTL.FE.IN')]
fps=female_population.sort_values(by='2022',ascending=False)
tf=fps.head(10)

# %% [markdown]
# ## Male Population

# %%
male_population=df[(df['Series Code']=='SP.POP.TOTL.MA.IN')]
mps=male_population.sort_values(by='2022',ascending=False)
tm=mps.head(10)

# %%
total_population_sort = total_population.sort_values(by='2022',ascending=False)

# %%
top_ten=total_population_sort.head(10)  #highest population
b_ten=total_population_sort.tail(10)   #lowest popultaion

# %% [markdown]
# ## Total population(2022)

# %%
plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x='2022',y='Country Name',data=top_ten)
plt.title("Top 10 Countries with according to Populations (2022)")
plt.xlabel('Total population',fontsize=10)
plt.ylabel('Country',fontsize=10)
plt.show()

plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x='2022',y='Country Name',data=b_ten)
plt.title("Bottom 10 Countries according to Total Populations (2022)")
plt.xlabel('Total population',fontsize=10)
plt.ylabel('Country',fontsize=10)
plt.show()

# %% [markdown]
# ## Total population(2011)

# %%
total_population_sort11 = total_population.sort_values(by='2011',ascending=False) 
t11=total_population_sort11.head(10)
b11=total_population_sort11.tail(10)
plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x='2011',y='Country Name',data=t11)
plt.title('Year 2011',fontsize=10)
plt.title("Top 10 Countries with according to Populations (2011)")
plt.xlabel('Total population',fontsize=10)
plt.ylabel('Country',fontsize=10)
plt.show()


plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x='2011',y='Country Name',data=b11)
plt.title('Year 2011',fontsize=10)
plt.title("Bottom 10 Countries according to Total Populations (2011)")
plt.xlabel('Total population',fontsize=10)
plt.ylabel('Country',fontsize=10)
plt.show()

# %% [markdown]
# ## Total population(2001)

# %%
total_population_sort11 = total_population.sort_values(by='2001',ascending=False) 
t01=total_population_sort11.head(10)
b01=total_population_sort11.tail(10)
plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x='2001',y='Country Name',data=t01)
plt.title('Year 2001',fontsize=10)
plt.title("Top 10 Countries with according to Populations (2001)")
plt.xlabel('Total population',fontsize=10)
plt.ylabel('Country',fontsize=10)
plt.show()


plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x='2001',y='Country Name',data=b01)
plt.title('Year 2001',fontsize=10)
plt.title("Bottom 10 Countries according to Total Populations (2001)")
plt.xlabel('Total population',fontsize=10)
plt.ylabel('Country',fontsize=10)
plt.show()

# %%
merge_data=pd.merge(mps,fps,on="Country Name",suffixes=("_m","_f")) #marged the male and female population data set

# %%
merge_data["Total Population"] = merge_data["2022_m"] + merge_data["2022_f"] #added a column called total population that stores the data of total population

# %%
sorted_data = merge_data.sort_values(by="Total Population", ascending=False)
top_10_countries = sorted_data.head(10) #sortted data
b_10_countries = sorted_data.tail(10)

# %% [markdown]
# ## Male and Female population(2022)

# %%
# Create the stacked bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x="Country Name", y="2022_f", data=top_10_countries, color="pink", label="Female Population")
sns.barplot(x="Country Name", y="2022_m", data=top_10_countries, bottom=top_10_countries["2022_f"], color="cyan", label="Male Population")
plt.title("Top 10 Countries with Male and Female Populations (2022)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(x="Country Name", y="2022_f", data=b_10_countries, color="pink", label="Female Population")
sns.barplot(x="Country Name", y="2022_m", data=b_10_countries, bottom=b_10_countries["2022_f"], color="cyan", label="Male Population")
plt.title("Bottom 10 Countries with Male and Female Populations (2022)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# ## Male and Female population(2011)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x="Country Name", y="2011_f", data=top_10_countries, color="pink", label="Female Population")
sns.barplot(x="Country Name", y="2011_m", data=top_10_countries, bottom=top_10_countries["2011_f"], color="cyan", label="Male Population")
plt.title("Top 10 Countries with Male and Female Populations (2011)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(x="Country Name", y="2011_f", data=b_10_countries, color="pink", label="Female Population")
sns.barplot(x="Country Name", y="2011_m", data=b_10_countries, bottom=b_10_countries["2011_f"], color="cyan", label="Male Population")
plt.title("Bottom 10 Countries with Male and Female Populations (2011)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# ## Male and Female population(2001)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x="Country Name", y="2022_f", data=top_10_countries, color="pink", label="Female Population")
sns.barplot(x="Country Name", y="2022_m", data=top_10_countries, bottom=top_10_countries["2022_f"], color="cyan", label="Male Population")
plt.title("Top 10 Countries with Male and Female Populations (2022)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(x="Country Name", y="2022_f", data=b_10_countries, color="pink", label="Female Population")
sns.barplot(x="Country Name", y="2022_m", data=b_10_countries, bottom=b_10_countries["2022_f"], color="cyan", label="Male Population")
plt.title("Bottom 10 Countries with Male and Female Populations (2022)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()
